# %%
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv('tmdb_5000_movies.csv')
credits=pd.read_csv('tmdb_5000_credits.csv')

# %%
movies=movies.merge(credits,on="title")

# %%
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4804                                                NaN    9367
# 4805                                                NaN   72766
# 4806  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4807                        http://shanghaicalling.com/  126186
# 4808                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4804  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4805                                                 []                en
# 4806  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4807                                                 []                en
# 4808  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4804  El Mariachi just wants to play his guitar and ...   14.269792
# 4805  A newlywed couple's honeymoon is upended by th...    0.642552
# 4806  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4807  When ambitious New York attorney Sam is sent t...    0.857008
# 4808  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  ... runtime  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4           [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
# ...                                                 ...  ...     ...
# 4804           [{"name": "Columbia Pictures", "id": 5}]  ...    81.0
# 4805                                                 []  ...    85.0
# 4806  [{"name": "Front Street Pictures", "id": 3958}...  ...   120.0
# 4807                                                 []  ...    98.0
# 4808  [{"name": "rusty bear entertainment", "id": 87...  ...    90.0
#
#                                        spoken_languages    status  \
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1              [{"iso_639_1": "en", "name": "English"}]  Released
# 2     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3              [{"iso_639_1": "en", "name": "English"}]  Released
# 4              [{"iso_639_1": "en", "name": "English"}]  Released
# ...                                                 ...       ...
# 4804      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]  Released
# 4805                                                 []  Released
# 4806           [{"iso_639_1": "en", "name": "English"}]  Released
# 4807           [{"iso_639_1": "en", "name": "English"}]  Released
# 4808           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4804  He didn't come looking for trouble, but troubl...
# 4805  A newlywed couple's honeymoon is upended by th...
# 4806                                                NaN
# 4807                           A New Yorker in Shanghai
# 4808                                                NaN
#
#                                          title vote_average vote_count  \
# 0                                       Avatar          7.2      11800
# 1     Pirates of the Caribbean: At World's End          6.9       4500
# 2                                      Spectre          6.3       4466
# 3                        The Dark Knight Rises          7.6       9106
# 4                                  John Carter          6.1       2124
# ...                                        ...          ...        ...
# 4804                               El Mariachi          6.6        238
# 4805                                 Newlyweds          5.9          5
# 4806                 Signed, Sealed, Delivered          7.0          6
# 4807                          Shanghai Calling          5.7          7
# 4808                         My Date with Drew          6.3         16
#
#      movie_id                                               cast  \
# 0       19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1         285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2      206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3       49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4       49529  [{"cast_id": 5, "character": "John Carter", "c...
# ...       ...                                                ...
# 4804     9367  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4805    72766  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4806   231617  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4807   126186  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4808    25975  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4804  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4805  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4806  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4807  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4808  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4809 rows x 23 columns]

# %%
movies=movies[['genres','movie_id','keywords','title','overview','popularity','runtime','vote_average','vote_count','cast','crew']]

# %%
movies.isnull().sum()
# Out:
# genres          0
# movie_id        0
# keywords        0
# title           0
# overview        3
# popularity      0
# runtime         2
# vote_average    0
# vote_count      0
# cast            0
# crew            0
# dtype: int64

# %%
movies.dropna(inplace=True)
movies.duplicated().sum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\2713813644.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(inplace=True)
# 0

# %%
def seperate(obj):
    l=[]
    for i in ast.literal_eval(obj):
        l.append(i['name'])
    return l

# %%
import ast

# %%
movies['genres']=movies['genres'].apply(seperate)
movies['keywords']=movies['keywords'].apply(seperate)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\3617311741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres']=movies['genres'].apply(seperate)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\3617311741.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['keywords']=movies['keywords'].apply(seperate)

# %%
def getCharacters(data):
    l=[]
    counter=0
    for i in ast.literal_eval(data):
        if counter!=5:
            l.append(i['name'])
            counter+=1;
        else:
            break
    return l

# %%
movies['cast']=movies['cast'].apply(getCharacters)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\118188224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['cast']=movies['cast'].apply(getCharacters)

# %%
def getDirector(data):
    l=[]
    for i in ast.literal_eval(data):
        if i['job']=='Director':
            l.append(i['name'])
    return l

# %%
movies['crew']=movies['crew'].apply(getDirector)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\1022749762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['crew']=movies['crew'].apply(getDirector)

# %%
movies['overview']=movies['overview'].apply(lambda x:x.split())
movies['genres']=movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords']=movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast']=movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew']=movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\2951953192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['overview']=movies['overview'].apply(lambda x:x.split())
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\2951953192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres']=movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\2951953192.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['keywords']=movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\2951953192.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['cast']=movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\2951953192.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['crew']=movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies
# Out:
#                                             genres  movie_id  \
# 0     [Action, Adventure, Fantasy, ScienceFiction]     19995
# 1                     [Adventure, Fantasy, Action]       285
# 2                       [Action, Adventure, Crime]    206647
# 3                 [Action, Crime, Drama, Thriller]     49026
# 4              [Action, Adventure, ScienceFiction]     49529
# ...                                            ...       ...
# 4804                     [Action, Crime, Thriller]      9367
# 4805                             [Comedy, Romance]     72766
# 4806             [Comedy, Drama, Romance, TVMovie]    231617
# 4807                                            []    126186
# 4808                                 [Documentary]     25975
#
#                                                keywords  \
# 0     [cultureclash, future, spacewar, spacecolony, ...
# 1     [ocean, drugabuse, exoticisland, eastindiatrad...
# 2     [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3     [dccomics, crimefighter, terrorist, secretiden...
# 4     [basedonnovel, mars, medallion, spacetravel, p...
# ...                                                 ...
# 4804  [unitedstates–mexicobarrier, legs, arms, paper...
# 4805                                                 []
# 4806  [date, loveatfirstsight, narration, investigat...
# 4807                                                 []
# 4808           [obsession, camcorder, crush, dreamgirl]
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  popularity  runtime  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...  150.437577    162.0
# 1     [Captain, Barbossa,, long, believed, to, be, d...  139.082615    169.0
# 2     [A, cryptic, message, from, Bond’s, past, send...  107.376788    148.0
# 3     [Following, the, death, of, District, Attorney...  112.312950    165.0
# 4     [John, Carter, is, a, war-weary,, former, mili...   43.926995    132.0
# ...                                                 ...         ...      ...
# 4804  [El, Mariachi, just, wants, to, play, his, gui...   14.269792     81.0
# 4805  [A, newlywed, couple's, honeymoon, is, upended...    0.642552     85.0
# 4806  ["Signed,, Sealed,, Delivered", introduces, a,...    1.444476    120.0
# 4807  [When, ambitious, New, York, attorney, Sam, is...    0.857008     98.0
# 4808  [Ever, since, the, second, grade, when, he, fi...    1.929883     90.0
#
#       vote_average  vote_count  \
# 0              7.2       11800
# 1              6.9        4500
# 2              6.3        4466
# 3              7.6        9106
# 4              6.1        2124
# ...            ...         ...
# 4804           6.6         238
# 4805           5.9           5
# 4806           7.0           6
# 4807           5.7           7
# 4808           6.3          16
#
#                                                    cast  \
# 0     [SamWorthington, ZoeSaldana, SigourneyWeaver, ...
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley, Ste...
# 2     [DanielCraig, ChristophWaltz, LéaSeydoux, Ralp...
# 3     [ChristianBale, MichaelCaine, GaryOldman, Anne...
# 4     [TaylorKitsch, LynnCollins, SamanthaMorton, Wi...
# ...                                                 ...
# 4804  [CarlosGallardo, JaimedeHoyos, PeterMarquardt,...
# 4805  [EdwardBurns, KerryBishé, MarshaDietlein, Cait...
# 4806  [EricMabius, KristinBooth, CrystalLowe, GeoffG...
# 4807  [DanielHenney, ElizaCoupe, BillPaxton, AlanRuc...
# 4808  [DrewBarrymore, BrianHerzlinger, CoreyFeldman,...
#
#                                        crew
# 0                            [JamesCameron]
# 1                           [GoreVerbinski]
# 2                               [SamMendes]
# 3                        [ChristopherNolan]
# 4                           [AndrewStanton]
# ...                                     ...
# 4804                      [RobertRodriguez]
# 4805                          [EdwardBurns]
# 4806                           [ScottSmith]
# 4807                           [DanielHsia]
# 4808  [BrianHerzlinger, JonGunn, BrettWinn]
#
# [4806 rows x 11 columns]

# %%
movies['tags']=movies['overview']+movies['genres']+movies['keywords']+movies['cast']+movies['crew']
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\694219746.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags']=movies['overview']+movies['genres']+movies['keywords']+movies['cast']+movies['crew']

# %%
movies['tags']=movies['tags'].apply(lambda x:" ".join(x))
movies['tags']=movies['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\3571225651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags']=movies['tags'].apply(lambda x:" ".join(x))
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\3571225651.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags']=movies['tags'].apply(lambda x:x.lower())

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words='english')

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(data):
    y=[]
    for i in data.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
movies['tags']=movies['tags'].apply(stem)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\4136005365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags']=movies['tags'].apply(stem)

# %%
movies
# Out:
#                                             genres  movie_id  \
# 0     [Action, Adventure, Fantasy, ScienceFiction]     19995
# 1                     [Adventure, Fantasy, Action]       285
# 2                       [Action, Adventure, Crime]    206647
# 3                 [Action, Crime, Drama, Thriller]     49026
# 4              [Action, Adventure, ScienceFiction]     49529
# ...                                            ...       ...
# 4804                     [Action, Crime, Thriller]      9367
# 4805                             [Comedy, Romance]     72766
# 4806             [Comedy, Drama, Romance, TVMovie]    231617
# 4807                                            []    126186
# 4808                                 [Documentary]     25975
#
#                                                keywords  \
# 0     [cultureclash, future, spacewar, spacecolony, ...
# 1     [ocean, drugabuse, exoticisland, eastindiatrad...
# 2     [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3     [dccomics, crimefighter, terrorist, secretiden...
# 4     [basedonnovel, mars, medallion, spacetravel, p...
# ...                                                 ...
# 4804  [unitedstates–mexicobarrier, legs, arms, paper...
# 4805                                                 []
# 4806  [date, loveatfirstsight, narration, investigat...
# 4807                                                 []
# 4808           [obsession, camcorder, crush, dreamgirl]
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  popularity  runtime  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...  150.437577    162.0
# 1     [Captain, Barbossa,, long, believed, to, be, d...  139.082615    169.0
# 2     [A, cryptic, message, from, Bond’s, past, send...  107.376788    148.0
# 3     [Following, the, death, of, District, Attorney...  112.312950    165.0
# 4     [John, Carter, is, a, war-weary,, former, mili...   43.926995    132.0
# ...                                                 ...         ...      ...
# 4804  [El, Mariachi, just, wants, to, play, his, gui...   14.269792     81.0
# 4805  [A, newlywed, couple's, honeymoon, is, upended...    0.642552     85.0
# 4806  ["Signed,, Sealed,, Delivered", introduces, a,...    1.444476    120.0
# 4807  [When, ambitious, New, York, attorney, Sam, is...    0.857008     98.0
# 4808  [Ever, since, the, second, grade, when, he, fi...    1.929883     90.0
#
#       vote_average  vote_count  \
# 0              7.2       11800
# 1              6.9        4500
# 2              6.3        4466
# 3              7.6        9106
# 4              6.1        2124
# ...            ...         ...
# 4804           6.6         238
# 4805           5.9           5
# 4806           7.0           6
# 4807           5.7           7
# 4808           6.3          16
#
#                                                    cast  \
# 0     [SamWorthington, ZoeSaldana, SigourneyWeaver, ...
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley, Ste...
# 2     [DanielCraig, ChristophWaltz, LéaSeydoux, Ralp...
# 3     [ChristianBale, MichaelCaine, GaryOldman, Anne...
# 4     [TaylorKitsch, LynnCollins, SamanthaMorton, Wi...
# ...                                                 ...
# 4804  [CarlosGallardo, JaimedeHoyos, PeterMarquardt,...
# 4805  [EdwardBurns, KerryBishé, MarshaDietlein, Cait...
# 4806  [EricMabius, KristinBooth, CrystalLowe, GeoffG...
# 4807  [DanielHenney, ElizaCoupe, BillPaxton, AlanRuc...
# 4808  [DrewBarrymore, BrianHerzlinger, CoreyFeldman,...
#
#                                    crew  \
# 0                          JamesCameron
# 1                         GoreVerbinski
# 2                             SamMendes
# 3                      ChristopherNolan
# 4                         AndrewStanton
# ...                                 ...
# 4804                    RobertRodriguez
# 4805                        EdwardBurns
# 4806                         ScottSmith
# 4807                         DanielHsia
# 4808  BrianHerzlinger JonGunn BrettWinn
#
#                                                    tags
# 0     in the 22nd century, a parapleg marin is dispa...
# 1     captain barbossa, long believ to be dead, ha c...
# 2     a cryptic messag from bond’ past send him on a...
# 3     follow the death of district attorney harvey d...
# 4     john carter is a war-weary, former militari ca...
# ...                                                 ...
# 4804  el mariachi just want to play hi guitar and ca...
# 4805  a newlyw couple' honeymoon is upend by the arr...
# 4806  "signed, sealed, delivered" introduc a dedic q...
# 4807  when ambiti new york attorney sam is sent to s...
# 4808  ever sinc the second grade when he first saw h...
#
# [4806 rows x 12 columns]

# %%
movies['crew']=movies['crew'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\1941945005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['crew']=movies['crew'].apply(lambda x:" ".join(x))

# %%
C=movies['vote_average'].mean()

# %%
m=movies['vote_count'].quantile(0.9)

# %%
def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
movies['score']=movies.apply(weighted_rating,axis=1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8116\866291161.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['score']=movies.apply(weighted_rating,axis=1)

# %%
movies
# Out:
#                                             genres  movie_id  \
# 0     [Action, Adventure, Fantasy, ScienceFiction]     19995
# 1                     [Adventure, Fantasy, Action]       285
# 2                       [Action, Adventure, Crime]    206647
# 3                 [Action, Crime, Drama, Thriller]     49026
# 4              [Action, Adventure, ScienceFiction]     49529
# ...                                            ...       ...
# 4804                     [Action, Crime, Thriller]      9367
# 4805                             [Comedy, Romance]     72766
# 4806             [Comedy, Drama, Romance, TVMovie]    231617
# 4807                                            []    126186
# 4808                                 [Documentary]     25975
#
#                                                keywords  \
# 0     [cultureclash, future, spacewar, spacecolony, ...
# 1     [ocean, drugabuse, exoticisland, eastindiatrad...
# 2     [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3     [dccomics, crimefighter, terrorist, secretiden...
# 4     [basedonnovel, mars, medallion, spacetravel, p...
# ...                                                 ...
# 4804  [unitedstates–mexicobarrier, legs, arms, paper...
# 4805                                                 []
# 4806  [date, loveatfirstsight, narration, investigat...
# 4807                                                 []
# 4808           [obsession, camcorder, crush, dreamgirl]
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  popularity  runtime  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...  150.437577    162.0
# 1     [Captain, Barbossa,, long, believed, to, be, d...  139.082615    169.0
# 2     [A, cryptic, message, from, Bond’s, past, send...  107.376788    148.0
# 3     [Following, the, death, of, District, Attorney...  112.312950    165.0
# 4     [John, Carter, is, a, war-weary,, former, mili...   43.926995    132.0
# ...                                                 ...         ...      ...
# 4804  [El, Mariachi, just, wants, to, play, his, gui...   14.269792     81.0
# 4805  [A, newlywed, couple's, honeymoon, is, upended...    0.642552     85.0
# 4806  ["Signed,, Sealed,, Delivered", introduces, a,...    1.444476    120.0
# 4807  [When, ambitious, New, York, attorney, Sam, is...    0.857008     98.0
# 4808  [Ever, since, the, second, grade, when, he, fi...    1.929883     90.0
#
#       vote_average  vote_count  \
# 0              7.2       11800
# 1              6.9        4500
# 2              6.3        4466
# 3              7.6        9106
# 4              6.1        2124
# ...            ...         ...
# 4804           6.6         238
# 4805           5.9           5
# 4806           7.0           6
# 4807           5.7           7
# 4808           6.3          16
#
#                                                    cast  \
# 0     [SamWorthington, ZoeSaldana, SigourneyWeaver, ...
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley, Ste...
# 2     [DanielCraig, ChristophWaltz, LéaSeydoux, Ralp...
# 3     [ChristianBale, MichaelCaine, GaryOldman, Anne...
# 4     [TaylorKitsch, LynnCollins, SamanthaMorton, Wi...
# ...                                                 ...
# 4804  [CarlosGallardo, JaimedeHoyos, PeterMarquardt,...
# 4805  [EdwardBurns, KerryBishé, MarshaDietlein, Cait...
# 4806  [EricMabius, KristinBooth, CrystalLowe, GeoffG...
# 4807  [DanielHenney, ElizaCoupe, BillPaxton, AlanRuc...
# 4808  [DrewBarrymore, BrianHerzlinger, CoreyFeldman,...
#
#                                    crew  \
# 0                          JamesCameron
# 1                         GoreVerbinski
# 2                             SamMendes
# 3                      ChristopherNolan
# 4                         AndrewStanton
# ...                                 ...
# 4804                    RobertRodriguez
# 4805                        EdwardBurns
# 4806                         ScottSmith
# 4807                         DanielHsia
# 4808  BrianHerzlinger JonGunn BrettWinn
#
#                                                    tags     score
# 0     in the 22nd century, a parapleg marin is dispa...  7.050318
# 1     captain barbossa, long believ to be dead, ha c...  6.665370
# 2     a cryptic messag from bond’ past send him on a...  6.239548
# 3     follow the death of district attorney harvey d...  7.346090
# 4     john carter is a war-weary, former militari ca...  6.096866
# ...                                                 ...       ...
# 4804  el mariachi just want to play hi guitar and ca...  6.151144
# 4805  a newlyw couple' honeymoon is upend by the arr...  6.092736
# 4806  "signed, sealed, delivered" introduc a dedic q...  6.096197
# 4807  when ambiti new york attorney sam is sent to s...  6.091772
# 4808  ever sinc the second grade when he first saw h...  6.095035
#
# [4806 rows x 13 columns]

# %%
movie_list=movies[movies['crew']=='JamesCameron']
movie_list=movie_list.sort_values('score',ascending=False)
movie_list
# Out:
#                                              genres  movie_id  \
# 25                       [Drama, Romance, Thriller]       597
# 279              [Action, Thriller, ScienceFiction]       280
# 2409     [Horror, Action, Thriller, ScienceFiction]       679
# 0      [Action, Adventure, Fantasy, ScienceFiction]     19995
# 3444             [Action, Thriller, ScienceFiction]       218
# 587   [Adventure, Action, Thriller, ScienceFiction]      2756
# 282                              [Action, Thriller]     36955
#
#                                                keywords  \
# 25    [shipwreck, iceberg, ship, panic, titanic, oce...
# 279   [cyborg, shotgun, post-apocalyptic, dystopia, ...
# 2409  [android, extraterrestrialtechnology, spacemar...
# 0     [cultureclash, future, spacewar, spacecolony, ...
# 3444  [savingtheworld, artificialintelligence, rebel...
# 587   [ocean, sea, divingsuit, flyingsaucer, nuclear...
# 282   [spy, terrorist, florida, gun, kidnapping, hor...
#
#                            title  \
# 25                       Titanic
# 279   Terminator 2: Judgment Day
# 2409                      Aliens
# 0                         Avatar
# 3444              The Terminator
# 587                    The Abyss
# 282                    True Lies
#
#                                                overview  popularity  runtime  \
# 25    [84, years, later,, a, 101-year-old, woman, na...  100.025899    194.0
# 279   [Nearly, 10, years, have, passed, since, Sarah...  101.741550    137.0
# 2409  [When, Ripley's, lifepod, is, found, by, a, sa...   67.660940    137.0
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...  150.437577    162.0
# 3444  [In, the, post-apocalyptic, future,, reigning,...   74.234793    108.0
# 587   [A, civilian, oil, rig, crew, is, recruited, t...   24.961625    139.0
# 282   [Harry, Tasker, is, a, secret, agent, for, the...   38.729418    141.0
#
#       vote_average  vote_count  \
# 25             7.5        7562
# 279            7.7        4185
# 2409           7.7        3220
# 0              7.2       11800
# 3444           7.3        4128
# 587            7.1         808
# 282            6.8        1116
#
#                                                    cast          crew  \
# 25    [KateWinslet, LeonardoDiCaprio, FrancesFisher,...  JamesCameron
# 279   [ArnoldSchwarzenegger, LindaHamilton, RobertPa...  JamesCameron
# 2409  [SigourneyWeaver, MichaelBiehn, JamesRemar, Pa...  JamesCameron
# 0     [SamWorthington, ZoeSaldana, SigourneyWeaver, ...  JamesCameron
# 3444  [ArnoldSchwarzenegger, MichaelBiehn, LindaHami...  JamesCameron
# 587   [EdHarris, MaryElizabethMastrantonio, MichaelB...  JamesCameron
# 282   [ArnoldSchwarzenegger, JamieLeeCurtis, TomArno...  JamesCameron
#
#                                                    tags     score
# 25    84 year later, a 101-year-old woman name rose ...  7.224035
# 279   nearli 10 year have pass sinc sarah connor wa ...  7.208293
# 2409  when ripley' lifepod is found by a salvag crew...  7.114620
# 0     in the 22nd century, a parapleg marin is dispa...  7.050318
# 3444  in the post-apocalypt future, reign tyrann sup...  6.927180
# 587   a civilian oil rig crew is recruit to conduct ...  6.399815
# 282   harri tasker is a secret agent for the unit st...  6.359584

# %%
def recommendUsingDirectors(Director):
    Director=Director.replace(" ","")
    movie_list=movies[movies['crew']==Director]
    movie_list=movie_list.sort_values('score',ascending=False).index
    
    for i in movie_list:
        print(movies.iloc[i].title)

# %%
recommendUsingDirectors('James Cameron')
# Out:
# Titanic
# Terminator 2: Judgment Day
# Aliens
# Avatar
# Good bye, Lenin!
# The Abyss
# True Lies

# %%
vectors=cv.fit_transform(movies['tags']).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors)

# %%
def recommend(movie):
    movie_index=movies[movies['title']==movie].index[0]
    distances=similarity[movie_index]
    movie_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:11]
    
    for i in movie_list:
        print(movies.iloc[i[0]].title)

# %%
recommend('Batman Begins')
# Out:
# The Dark Knight
# Batman
# Batman
# The Dark Knight Rises
# 10th & Wolf
# Rockaway
# Batman v Superman: Dawn of Justice
# Defendor
# Synecdoche, New York
# Sexy Beast

# %%
def recommendUsingCast(character):
    character=character.replace(" ","")
    movie_list=movies.sort_values('score',ascending=False)
    actors_list=list(enumerate(movie_list['cast']))

    for i in actors_list:
        if character in i[1]:
            print(movie_list.iloc[i[0]].title)

# %%
recommendUsingCast('Sam Worthington')
# Out:
# Avatar
# Everest
# Man on a Ledge
# The Debt
# Terminator Salvation
# Sabotage
# Wrath of the Titans
# Clash of the Titans

# %%
def recommendUsingGenre(genre):
    genre=genre.replace(" ","")
    movie_list=movies.sort_values('score',ascending=False)
    genres_list=list(enumerate(movie_list['genres']))
    
    counter=0

    for i in genres_list:
        if genre in i[1]:
            if counter!=10:
                print(movie_list.iloc[i[0]].title)
                counter+=1

# %%
recommendUsingGenre('Drama')
# Out:
# The Shawshank Redemption
# Fight Club
# The Dark Knight
# The Godfather
# Interstellar
# Forrest Gump
# Schindler's List
# Whiplash
# Inside Out
# The Green Mile
